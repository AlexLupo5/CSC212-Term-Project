# %% [markdown]
# #### The purpose of this is to generate expected output from our test case files and compare with the results of our own convex hull code

# %% [markdown]
# Imported ConvexHull structure from scipy to compare with ours ↓

# %%
from scipy.spatial import ConvexHull
import matplotlib.pyplot as plt

# %% [markdown]
# #### Python function to construct and plot convex hull given a file with the following format:
# (x1,y1)
# (x2,y2)
# (x3,y3)...

# %%
def constructHull(file_name):
    with open(file_name, 'r') as file:
        lines = file.readlines()

    # Parse values
    x_values = []
    y_values = []

    for line in lines:
        x, y = map(int, line[line.index('(') + 1:line.index(')')].split(','))
        x_values.append(x)
        y_values.append(y)
        
        
   
    points = list(zip(x_values, y_values))
        
    try:
        hull = ConvexHull(points)

        convex_hull_points = [points[i] for i in hull.vertices]
        print("Convex Hull Points:", convex_hull_points)

        # Plot the points
        plt.plot(*zip(*points), 'ro', label='All Points')

        # Plot the convex hull points
        plt.plot(*zip(*[points[i] for i in hull.vertices]), 'bo', label='Convex Hull Points')

        # Plot the convex hull edges
        for simplex in hull.simplices:
            plt.plot([points[i][0] for i in simplex] + [points[simplex[0]][0]],
                        [points[i][1] for i in simplex] + [points[simplex[0]][1]], 'k-')

        plt.title('Convex Hull Visualization')
        plt.xlabel('X-axis')
        plt.ylabel('Y-axis')
        plt.legend()
        plt.show()
            
    except Exception as e:
        print("Cannot construct convex hull. Plotting original points.")

        # Plot the points without attempting to compute the convex hull
        plt.plot(*zip(*points), 'ro', label='All Points')
        plt.title('Point Visualization')
        plt.xlabel('X-axis')
        plt.ylabel('Y-axis')
        plt.legend()
        plt.show()

# %% [markdown]
# # TEST CASE 1: 100 Points

# %% [markdown]
# ## Expected output:

# %%
constructHull('test_cases/100_points.txt')
# Out:
# Convex Hull Points: [(-96, 77), (-100, -33), (-95, -98), (-15, -99), (69, -98), (98, -83), (100, 26), (84, 93), (77, 94), (25, 100), (-27, 99), (-93, 80)]

# %% [markdown]
# ## Our output:

# %% [markdown]
# ![image.png](attachment:e2f6a012-18b6-4f3d-a34e-115127cc7316.png)

# %% [markdown]
# #### Our .dot file visualization(s):

# %% [markdown]
# ![image.png](attachment:56d235a1-8a0e-4c6f-a8f0-c315398840ee.png)

# %% [markdown]
# ### Our results seem to match!

# %% [markdown]
# ---

# %% [markdown]
# # TEST CASE 2: Empty File

# %% [markdown]
# ## Expected output:

# %%
constructHull('test_cases/empty_test.txt')
# Out:
# Cannot construct convex hull. Plotting original points.

# %% [markdown]
# ## Our output:

# %% [markdown]
# ![image.png](attachment:abf6695b-6530-4de2-a53e-ff56f754e8df.png)

# %% [markdown]
# ### Our results match!

# %% [markdown]
# ---

# %% [markdown]
# # TEST CASE 3: Duplicate Points (more than 3 points)

# %% [markdown]
# ## Expected output:

# %%
constructHull('test_cases/equal_points.txt')
# Out:
# Cannot construct convex hull. Plotting original points.

# %% [markdown]
# ## Our output:

# %% [markdown]
# ![image.png](attachment:4342cd02-2d10-4d85-821a-c42ee9c28ec0.png)

# %% [markdown]
# #### Our .dot file visualization(s):

# %% [markdown]
# ![graphviz (1).png](attachment:2b103ee2-f40d-4d77-9197-e60ddd2ba79e.png)

# %% [markdown]
# ---

# %% [markdown]
# # TEST CASE 4: Four Poles With Duplicate Points

# %% [markdown]
# ## Expected output:

# %%
constructHull('test_cases/four_poles_with_duplicates.txt')
# Out:
# Convex Hull Points: [(1, 4), (1, 1), (4, 1), (4, 4)]

# %% [markdown]
# ## Our output:

# %% [markdown]
# ![image.png](attachment:ef8882ff-d7f1-4834-8d9d-f79c1c92da92.png)

# %% [markdown]
# #### Our .dot file visualizations:

# %% [markdown]
# ![graphviz (2).png](attachment:a3fdc3f2-5fc8-4658-addb-32603a598e4f.png)

# %% [markdown]
# ### Our results match!

# %% [markdown]
# ---

# %% [markdown]
# # TEST CASE 5: Horizontal Line (same y values)

# %% [markdown]
# ## Expected output:

# %%
constructHull('test_cases/horizontal_line.txt')
# Out:
# Cannot construct convex hull. Plotting original points.

# %% [markdown]
# ## Our output:

# %% [markdown]
# ![image.png](attachment:35a584d2-75ae-41eb-b324-42419d8b23ec.png)

# %% [markdown]
# #### Our .dot file visualization(s):

# %% [markdown]
# ![image.png](attachment:f8e2eb5d-bc86-491b-9cd6-9682c7fa0176.png)

# %% [markdown]
# ### Our results match!

# %% [markdown]
# ---

# %% [markdown]
# # TEST CASE 6: One Point

# %% [markdown]
# ## Expected output:

# %%
constructHull('test_cases/one_point.txt')
# Out:
# Cannot construct convex hull. Plotting original points.

# %% [markdown]
# ## Our output:

# %% [markdown]
# ![image.png](attachment:2adc3525-c478-44e2-9c2d-72feb6fe9346.png)

# %% [markdown]
# #### Our .dot file visualization(s):

# %% [markdown]
# ![image.png](attachment:bffe5d88-7bdf-465b-8d6d-7dcdf6306808.png)

# %% [markdown]
# ### Our results match!

# %% [markdown]
# ---

# %% [markdown]
# # TEST CASE 7: Points On a Parabola

# %% [markdown]
# ## Expected output:

# %%
constructHull('test_cases/parabola_points.txt')
# Out:
# Convex Hull Points: [(6, 19), (-6, 19), (-4, 9), (-2, 3), (0, 1), (2, 3), (4, 9)]

# %% [markdown]
# ## Our output:

# %% [markdown]
# ![image.png](attachment:89d99dda-2d8d-426f-b721-28305b84f6f7.png)

# %% [markdown]
# #### Our .dot file visualization(s):

# %% [markdown]
# ![image.png](attachment:a60b5b82-4bad-433f-a7c2-fb929b75caa3.png)

# %% [markdown]
# ### Our results match!

# %% [markdown]
# ---

# %% [markdown]
# # TEST CASE 8: Random Points In a Square

# %% [markdown]
# ## Expected output:

# %%
constructHull('test_cases/random_square_points.txt')
# Out:
# Convex Hull Points: [(0, 100), (0, 0), (100, 0), (100, 100)]

# %% [markdown]
# ## Our output:

# %% [markdown]
# ![image.png](attachment:f690fe1b-5571-4398-a8a6-e3cb124541cd.png)

# %% [markdown]
# #### Our .dot file visualization(s):

# %% [markdown]
# ![graphviz (4).png](attachment:11e73c8f-34f2-4d67-abe1-de4b930cac18.png)

# %% [markdown]
# ### Our results match!

# %% [markdown]
# ---

# %% [markdown]
# # TEST CASE 9: Two Points

# %% [markdown]
# ## Expected output:

# %%
constructHull('test_cases/two_points.txt')
# Out:
# Cannot construct convex hull. Plotting original points.

# %% [markdown]
# ## Our output:

# %% [markdown]
# ![image.png](attachment:213e0d84-9d9d-4f7a-a91e-1eb77476419f.png)

# %% [markdown]
# #### Our .dot file visualization(s):

# %% [markdown]
# ![image.png](attachment:08086eb1-8c81-4617-a0cc-0b9b43973f91.png)

# %% [markdown]
# ### Our results match!

# %% [markdown]
# ---

# %% [markdown]
# # TEST CASE 10: Vertical Line (same x values)

# %% [markdown]
# ## Expected output:

# %%
constructHull('test_cases/vertical_line.txt')
# Out:
# Cannot construct convex hull. Plotting original points.

# %% [markdown]
# ## Our output:

# %% [markdown]
# ![image.png](attachment:1e51dc71-a379-4dfb-be59-209e45aa4580.png)

# %% [markdown]
# #### Our .dot file visualization(s):

# %% [markdown]
# ![image.png](attachment:5715f86f-2fbc-4e99-af97-c165de4a50d3.png)

# %% [markdown]
# ### Our results match!

# %% [markdown]
# ---

# %% [markdown]
# # We passed our test cases!
